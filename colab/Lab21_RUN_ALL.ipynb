# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.59s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = "8"         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=8
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# config.json: 100% 2.76k/2.76k [00:00<00:00, 5.38MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 49.2MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 78.8MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 92.6MB/s]
#
# tokenizer.json: downloading bytes:  31% 6.23M/20.0M [00:00<00:01, 10.3MB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 10.2MB/s,  618kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 32.6MB/s, 1.98MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 6.15MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 6.29MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 31.7MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 19s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# ⚠ EVAL_LIMIT=8 — SMOKE MODE, not a submittable run
# target=8  regression=8  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 191MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Downloading bytes:   0% 13.5M/9.32G [00:00<07:59, 19.4MB/s]
# Downloading bytes:   2% 190M/9.32G [00:01<00:43, 211MB/s,  201MB/s  ]
# Downloading bytes:   5% 487M/9.32G [00:02<00:50, 174MB/s,  173MB/s  ]
# Downloading bytes:   6% 513M/9.32G [00:03<00:55, 160MB/s,  174MB/s  ]
# Downloading bytes:   8% 774M/9.32G [00:04<00:58, 146MB/s,  141MB/s  ]
# Downloading bytes:  11% 1.03G/9.32G [00:05<00:42, 197MB/s,  188MB/s  ]
# Downloading bytes:  19% 1.82G/9.32G [00:08<00:30, 247MB/s,  247MB/s  ]
# Downloading bytes:  21% 1.97G/9.32G [00:09<00:49, 147MB/s,  181MB/s  ]
# Downloading bytes:  22% 2.07G/9.32G [00:10<00:45, 158MB/s,  166MB/s  ]
# Downloading bytes:  28% 2.60G/9.32G [00:12<00:24, 270MB/s,  258MB/s  ]
# Downloading bytes:  29% 2.71G/9.32G [00:13<00:38, 171MB/s,  176MB/s  ]
# Downloading bytes:  29% 2.75G/9.32G [00:13<00:38, 170MB/s,  171MB/s  ]
# Downloading bytes:  31% 2.93G/9.32G [00:14<00:38, 166MB/s,  167MB/s  ]
# Downloading bytes:  40% 3.72G/9.32G [00:19<00:33, 169MB/s,  160MB/s  ]
# Downloading bytes:  40% 3.74G/9.32G [00:19<00:40, 140MB/s,  169MB/s  ]
# Downloading bytes:  42% 3.87G/9.32G [00:20<00:37, 146MB/s,  162MB/s  ]
# Downloading bytes:  43% 3.99G/9.32G [00:20<00:28, 189MB/s,  182MB/s  ]
# Downloading bytes:  51% 4.79G/9.32G [00:24<00:26, 171MB/s,  188MB/s  ]
# Downloading bytes:  55% 5.13G/9.32G [00:26<00:14, 296MB/s,  273MB/s  ]
# Downloading bytes:  59% 5.50G/9.32G [00:27<00:12, 317MB/s,  307MB/s  ]
# Downloading bytes:  62% 5.76G/9.32G [00:28<00:11, 309MB/s,  302MB/s  ]
# Downloading bytes:  64% 5.95G/9.32G [00:30<00:32, 105MB/s,  112MB/s  ]
# Downloading bytes:  64% 5.97G/9.32G [00:30<00:27, 120MB/s,  105MB/s  ]
# Downloading bytes:  66% 6.17G/9.32G [00:32<00:23, 131MB/s,  123MB/s  ]
# Downloading bytes:  69% 6.45G/9.32G [00:35<00:16, 171MB/s,  163MB/s  ]
# Downloading bytes:  69% 6.47G/9.32G [00:35<00:18, 152MB/s,  171MB/s  ]
# Downloading bytes:  78% 7.26G/9.32G [00:38<00:06, 334MB/s,  337MB/s  ]
# Reconstructing (incomplete total...):  60% 5.63G/9.32G [00:40<00:29, 124MB/s,  244MB/s  ]
# Downloading bytes:  81% 7.57G/9.32G [00:41<00:09, 188MB/s,  169MB/s  ]
# Downloading bytes:  84% 7.82G/9.32G [00:43<00:09, 161MB/s,  152MB/s  ]
# Downloading bytes:  86% 8.03G/9.32G [00:44<00:05, 235MB/s,  219MB/s  ]
# Reconstructing (incomplete total...):  72% 6.69G/9.32G [00:45<00:15, 172MB/s,  189MB/s  ]
# Reconstructing (incomplete total...):  76% 7.07G/9.32G [00:45<00:08, 259MB/s,  172MB/s  ]
# Reconstructing (incomplete total...):  80% 7.49G/9.32G [00:48<00:10, 177MB/s,  259MB/s  ]
# Reconstructing (incomplete total...):  82% 7.67G/9.32G [00:50<00:09, 169MB/s,  177MB/s  ]
# Reconstructing (incomplete total...):  90% 8.42G/9.32G [00:50<00:02, 301MB/s,  169MB/s  ]
# Reconstructing (incomplete total...):  91% 8.50G/9.32G [00:51<00:02, 276MB/s,  301MB/s  ]
#
# Fetching 2 files:  50% 1/2 [00:51<00:51, 51.57s/it]
# Reconstructing (incomplete total...):  94% 8.81G/9.32G [00:53<00:02, 209MB/s,  276MB/s  ]
# Reconstructing (incomplete total...):  97% 9.06G/9.32G [00:54<00:01, 245MB/s,  209MB/s  ]
# Reconstructing (incomplete total...):  99% 9.23G/9.32G [00:55<00:00, 246MB/s,  245MB/s  ]
# Reconstructing (incomplete total...): 100% 9.32G/9.32G [00:55<00:00, 242MB/s,  246MB/s  ]
#
# Fetching 2 files: 100% 2/2 [00:55<00:00, 27.71s/it]
# Download complete: 100% 8.05G/8.05G [00:55<00:00, 235MB/s,  235MB/s  ]
# Download complete: 100% 8.05G/8.05G [00:55<00:00, 145MB/s,  235MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [00:55<00:00, 168MB/s,  242MB/s  ]
# Loading weights: 100% 426/426 [00:31<00:00, 13.48it/s]
#   [(a) base + naive prompt/target] batch 1/2     14s elapsed  ~   14s left
#   [(a) base + naive prompt/target] batch 2/2     26s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 8 prompts in 26s
#   [(a) base + naive prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(a) base + naive prompt/regression] batch 2/2     13s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 8 prompts in 13s
# (a) base + naive prompt      target=0.000  regression=0.750  format=0.000  3292ms
#   [(b) base + optimized prompt/target] batch 1/2      4s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 2/2      8s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 8 prompts in 8s
#   [(b) base + optimized prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(b) base + optimized prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 8 prompts in 12s
# (b) base + optimized prompt  target=0.688  regression=0.750  format=1.000  956ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.75,
#     "format": 0.0,
#     "latency_ms": 3291.702763624997,
#     "n": 8,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.6875,
#     "regression": 0.75,
#     "format": 1.0,
#     "latency_ms": 956.4447206250009,
#     "n": 8,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 8,
#   "n_regression": 8,
#   "eval_limit": 8,
#   "smoke_mode": true
# }
#
# -- NB2 ok in 162s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1017.05it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.34it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 5219.62 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 41340.39 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.386', 'grad_norm': '2.512', 'learning_rate': '8.83e-05', 'entropy': '1.033', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7716', 'epoch': '0.7111'}
# {'loss': '0.14', 'grad_norm': '0.6603', 'learning_rate': '6.434e-05', 'entropy': '0.2688', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9584', 'epoch': '1'}
# {'loss': '0.02926', 'grad_norm': '0.8134', 'learning_rate': '3.566e-05', 'entropy': '0.0398', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9889', 'epoch': '1.356'}
# {'loss': '0.01844', 'grad_norm': '0.2574', 'learning_rate': '1.17e-05', 'entropy': '0.02088', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9924', 'epoch': '1.711'}
# {'loss': '0.0255', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01567', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9957', 'epoch': '2'}
# {'train_runtime': '934.7', 'train_samples_per_second': '0.481', 'train_steps_per_second': '0.032', 'train_loss': '0.6271', 'epoch': '2'}
# 100% 30/30 [15:34<00:00, 31.15s/it]
# train 935s  final loss 0.6271
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 935.1,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6271,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 997s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 915.99it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.37it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1031.05it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.34it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6303.56 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45225.40 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.897', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8226', 'grad_norm': '1.869', 'learning_rate': '8.83e-05', 'entropy': '0.9386', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8422', 'epoch': '0.7111'}
# {'loss': '0.1461', 'grad_norm': '1.344', 'learning_rate': '6.434e-05', 'entropy': '0.2843', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9572', 'epoch': '1'}
# {'loss': '0.03955', 'grad_norm': '0.8586', 'learning_rate': '3.566e-05', 'entropy': '0.06537', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.987', 'epoch': '1.356'}
# {'loss': '0.02167', 'grad_norm': '0.2077', 'learning_rate': '1.17e-05', 'entropy': '0.03196', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9909', 'epoch': '1.711'}
# {'loss': '0.02624', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02323', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.995', 'epoch': '2'}
# {'train_runtime': '810.9', 'train_samples_per_second': '0.592', 'train_steps_per_second': '0.037', 'train_loss': '0.5366', 'epoch': '2'}
# 100% 30/30 [13:30<00:00, 27.03s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1018.16it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.38it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 9324.73 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 35561.02 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
# {'loss': '1.606', 'grad_norm': 'nan', 'learning_rate': '6.434e-06', 'entropy': '1.178', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7176', 'epoch': '1'}
# {'loss': '1.326', 'grad_norm': '4.63', 'learning_rate': '3.566e-06', 'entropy': '1.103', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.7564', 'epoch': '1.356'}
# {'loss': '1.141', 'grad_norm': '4.213', 'learning_rate': '1.17e-06', 'entropy': '1.077', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.7979', 'epoch': '1.711'}
# {'loss': '1.119', 'grad_norm': 'nan', 'learning_rate': '3.381e-08', 'entropy': '1.069', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.7905', 'epoch': '2'}
# {'train_runtime': '938', 'train_samples_per_second': '0.512', 'train_steps_per_second': '0.032', 'train_loss': '1.57', 'epoch': '2'}
# 100% 30/30 [15:38<00:00, 31.27s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 845.71it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:35<00:00, 12.16it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 9232.05 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45751.61 examples/s]
#   precision fix: recast 496/496 trainable tensors bf16 -> fp32 for the fp16 GradScaler
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.155', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.34', 'num_tokens': '7479', 'mean_token_accuracy': '0.656', 'epoch': '0.3556'}
# {'loss': '1.731', 'grad_norm': '3.368', 'learning_rate': '8.83e-05', 'entropy': '1.287', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7214', 'epoch': '0.7111'}
# {'loss': '0.2408', 'grad_norm': '1.019', 'learning_rate': '6.434e-05', 'entropy': '0.3825', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9382', 'epoch': '1'}
# {'loss': '0.0513', 'grad_norm': '1.023', 'learning_rate': '3.566e-05', 'entropy': '0.07534', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9829', 'epoch': '1.356'}
# {'loss': '0.03019', 'grad_norm': '0.3238', 'learning_rate': '1.17e-05', 'entropy': '0.0355', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9884', 'epoch': '1.711'}
# {'loss': '0.02674', 'grad_norm': '3.368', 'learning_rate': '3.381e-07', 'entropy': '0.03056', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.992', 'epoch': '2'}
# {'train_runtime': '999.1', 'train_samples_per_second': '0.48', 'train_steps_per_second': '0.03', 'train_loss': '0.7058', 'epoch': '2'}
# 100% 30/30 [16:39<00:00, 33.30s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.6271 | 935.1 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.5366 | 811.3 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 938.4 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 999.5 | 7.09 |
#
# -- NB4 ok in 2926s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.688 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 988.87it/s]
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Download complete: :           |  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.24it/s]
#   [ft/target] batch 1/2      7s elapsed  ~    7s left
#   [ft/target] batch 2/2     12s elapsed  ~    0s left
#   [ft/target] done: 8 prompts in 12s
#   [ft/regression] batch 1/2     11s elapsed  ~   11s left
#   [ft/regression] batch 2/2     22s elapsed  ~    0s left
#   [ft/regression] done: 8 prompts in 22s
# fine-tune: {'target': 0.9375, 'regression': 0.6666666666666666, 'format': 1.0, 'latency_ms': 1557.2461752499294, 'n': 8, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.75 | 0.0 | 3291.7 | 8 |
# | (b) base + optimized prompt | 0.6875 | 0.75 | 1.0 | 956.4 | 8 |
# | (c) LoRA fine-tune | 0.9375 | 0.6667 | 1.0 | 1557.2 | 8 |
# FAILED
#  - general capability regressed by 0.083 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1064.81it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.36it/s]
#   [attn_only/target] batch 1/2      4s elapsed  ~    4s left
#   [attn_only/target] batch 2/2      7s elapsed  ~    0s left
#   [attn_only/target] done: 8 prompts in 7s
# attn_only: target=0.938  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1011.65it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.38it/s]
#   [wrong_lr/target] batch 1/2     20s elapsed  ~   20s left
#   [wrong_lr/target] batch 2/2     40s elapsed  ~    0s left
#   [wrong_lr/target] done: 8 prompts in 40s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1005.11it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:35<00:00, 11.88it/s]
#   [qlora/target] batch 1/2      7s elapsed  ~    7s left
#   [qlora/target] batch 2/2     14s elapsed  ~    0s left
#   [qlora/target] done: 8 prompts in 14s
# qlora: target=0.844  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.9375 | 1.0 | 1557.2 | 8 |
# | attn_only | 0.9375 | 1.0 | 906.2 | 8 |
# | wrong_lr | 0.0 | 0.0 | 5002.5 | 8 |
# | qlora | 0.8438 | 1.0 | 1802.9 | 8 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 0 | Cho mình hỏi, mình đặt chuột không dây mã đơn VN232232. Cho tôi trả lạ | 1.0 | {"intent": "doi_tra", "urgency": "cao", "product": "chuột không dây", "sentiment": "tich_c |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 4 | Cho mình hỏi, mình đặt đèn bàn LED mã đơn VN339109. Vỡ khi nhận. Gấp.  | 1.0 | {"intent": "san_pham_loi", "urgency": "cao", "product": "đèn bàn LED", "sentiment": "trung |
# | 6 | Xin chào, mình đặt balo laptop mã đơn DH863123. Đổi size. Hỏi cho biết | 1.0 | {"intent": "doi_tra", "urgency": "thap", "product": "balo laptop", "sentiment": "tieu_cuc" |
# | 7 | Alo shop, mình đặt máy xay sinh tố mã đơn OD126693. Muốn đổi. Đã 3 ngà | 1.0 | {"intent": "doi_tra", "urgency": "trung_binh", "product": "máy xay sinh tố", "sentiment":  |
#
# -- NB5 ok in 271s
#
# ----------------------------------------
# stage timings
#   nb1        19s  (0.3 min)
#   nb2       162s  (2.7 min)
#   nb3       997s  (16.6 min)
#   nb4      2926s  (48.8 min)
#   nb5       271s  (4.5 min)
#   total    4374s (72.9 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 3.38s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [ FAIL ] full eval set used                               EVAL_LIMIT=8 — this run scored 8 target items, not the full set. Smoke mode is for iterating; unset EVAL_LIMIT and re-run NB2+NB5 to submit.
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.688
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 FAILED (target Δ +0.250, regression Δ -0.083)
# [ warn ] note                                             A FAILED verdict is fully gradeable — analyse it honestly in REPORT.md rather than loosening the gate.
#
# 23 passed · 1 warnings · 3 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 40
# drwxr-xr-x  2 root root 4096 Aug 21 09:21 .
# drwxr-xr-x 15 root root 4096 Aug 21 08:08 ..
# -rw-r--r--  1 root root  435 Aug 21 09:21 autopsy.json
# -rw-r--r--  1 root root  479 Aug 21 08:11 baselines_frozen.json
# -rw-r--r--  1 root root    0 Aug 21 08:04 .gitkeep
# -rw-r--r--  1 root root  592 Aug 21 08:09 mask_proof.json
# -rw-r--r--  1 root root 2206 Aug 21 09:21 qualitative.json
# -rw-r--r--  1 root root 1099 Aug 21 09:17 runs.csv
# -rw-r--r--  1 root root  277 Aug 21 08:09 template_check.json
# -rw-r--r--  1 root root  115 Aug 21 08:09 token_stats.json
# -rw-r--r--  1 root root  786 Aug 21 09:18 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,935.1,12.01,0.6271,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,811.3,12.02,0.5366,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,938.4,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,999.5,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.75,
#       "format": 0.0,
#       "latency_ms": 3291.7,
#       "n": 8
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.6875,
#       "regression": 0.75,
#       "format": 1.0,
#       "latency_ms": 956.4,
#       "n": 8
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.9375,
#       "regression": 0.6667,
#       "format": 1.0,
#       "latency_ms": 1557.2,
#       "n": 8
#     }
#   ],
#   "verdict": {
#     "passed": false,
#     "reasons": [
#       "general capability regressed by 0.083 (tolerance 0.020). See deck §14.3 — add 1-5% replay data."
#     ],
#     "target_delta": 0.25,
#     "regression_delta": -0.08333333333333337
#   },
#   "valid_trace_rate": 0.0
# }

# %%
# Nén tất cả file kết quả
# !zip -r lab21_results.zip results/ adapters/ submission/ -x "*/.git/*"
# Out:
#   adding: results/ (stored 0%)
#   adding: results/runs.csv (deflated 47%)
#   adding: results/token_stats.json (deflated 34%)
#   adding: results/.gitkeep (stored 0%)
#   adding: results/mask_proof.json (deflated 42%)
#   adding: results/template_check.json (deflated 36%)
#   adding: results/autopsy.json (deflated 67%)
#   adding: results/qualitative.json (deflated 71%)
#   adding: results/verdict.json (deflated 56%)
#   adding: results/baselines_frozen.json (deflated 52%)
#   adding: adapters/ (stored 0%)
#   adding: adapters/attn_only/ (stored 0%)
#   adding: adapters/attn_only/adapter_config.json (deflated 59%)
#   adding: adapters/attn_only/adapter_model.safetensors (deflated 8%)
#   adding: adapters/attn_only/README.md (deflated 65%)
#   adding: adapters/wrong_lr/ (stored 0%)
#   adding: adapters/wrong_lr/adapter_config.json (deflated 62%)
#   adding: adapters/wrong_lr/adapter_model.safetensors (deflated 10%)
#   adding: adapters/wrong_lr/README.md (deflated 65%)
#   adding: adapters/correct/ (stored 0%)
#   adding: adapters/correct/chat_template.jinja (deflated 76%)
#   adding: adapters/correct/adapter_config.json (deflated 62%)
#   adding: adapters/correct/tokenizer_config.json (deflated 65%)
#   adding: adapters/correct/tokenizer.json (deflated 80%)
#   adding: adapters/correct/adapter_model.safetensors (deflated 8%)
#   adding: adapters/correct/README.md (deflated 65%)
#   adding: adapters/qlora/ (stored 0%)
#   adding: adapters/qlora/adapter_config.json (deflated 62%)
#   adding: adapters/qlora/adapter_model.safetensors (deflated 8%)
#   adding: adapters/qlora/README.md (deflated 65%)
#   adding: adapters/.gitkeep (stored 0%)
#   adding: submission/ (stored 0%)
#   adding: submission/REFLECTION.md (deflated 35%)
#   adding: submission/REPORT.md (deflated 49%)
#   adding: submission/screenshots/ (stored 0%)
#   adding: submission/screenshots/.gitkeep (stored 0%)
